# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
plt.imshow(x_train[444])

# %%
x_train[444].shape
# Out:
# (32, 32, 3)

# %%
plt.imshow([[1,2,3],[3,4,5],[5,6,7]])

# %%
import numpy as np
a = np.random.random((4,4,3))
r = a.copy()
r[:,:,[1,2]] = 0
plt.imshow(r)

g = a.copy()
g[:,:,[0,2]] = 0
plt.imshow(g)

# %%
g = a.copy()
g[[3],[0],:] = 0
plt.imshow(g)

# %%
img_array = plt.imread("/Users/roxanneli/Desktop/IBM Machine Learning/dataset/IMG_8736.jpg")
img_array.shape
# Out:
# (3024, 4032, 3)

# %%
plt.imshow(img_array)

# %%
A = img_array.copy()
A[:,:,[2]] = 0
plt.imshow(A)
plt.imsave("yellow sky.jpg", A)

# %%
B = img_array.copy()
B[:,:,[0]] = 0
plt.imshow(B)
plt.imsave("green sky.jpg", B)

# %%
C = img_array.copy()
C[:,:,[1]] = 0
plt.imshow(C)
plt.imsave("pink sky.jpg", C)

# %%
D = img_array.copy()
D[:,:,[1,2]] = 0
plt.imshow(D)

# %%
E = img_array.copy()
E[:,:,[0,2]] = 0
plt.imshow(E)

# %%
F = img_array.copy()
F[:,:,[0,1]] = 0
F = F/255 * 2
plt.imshow(F)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
num_classes = 10

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
x_train.shape[1:]
# Out:
# (32, 32, 3)

# %%
model_1 = Sequential()

model_1.add(Conv2D(32, (5,5), strides=(2,2), padding='same',
                  input_shape = x_train.shape[1:]))
model_1.add(Activation('relu'))

model_1.add(Conv2D(32, (5,5), strides=(2,2)))
model_1.add(Activation('relu'))

model_1.add(MaxPooling2D(pool_size=(2,2)))
model_1.add(Dropout(0.25))

model_1.add(Flatten())
model_1.add(Dense(512))
model_1.add(Activation('relu'))
model_1.add(Dropout(0.5))
model_1.add(Dense(num_classes))
model_1.add(Activation('softmax'))

model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 16, 16, 32)        2432
# _________________________________________________________________
# activation (Activation)      (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 6, 6, 32)          25632
# _________________________________________________________________
# activation_1 (Activation)    (None, 6, 6, 32)          0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 3, 3, 32)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 3, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# ...

# %%
batch_size = 32

opt = keras.optimizers.RMSprop(lr = 0.0005, decay=1e-6)

model_1.compile(loss = 'categorical_crossentropy',
                optimizer = opt,
                metrics=['accuracy'])

model_1.fit(x_train, y_train, batch_size=batch_size, 
           epochs=15, validation_data=(x_test, y_test),
           shuffle=True)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 29s 19ms/step - loss: 1.7136 - accuracy: 0.3759 - val_loss: 1.5125 - val_accuracy: 0.4581
# Epoch 2/15
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.4413 - accuracy: 0.4792 - val_loss: 1.3461 - val_accuracy: 0.5231
# Epoch 3/15
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.3332 - accuracy: 0.5276 - val_loss: 1.2022 - val_accuracy: 0.5758
# Epoch 4/15
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2615 - accuracy: 0.5537 - val_loss: 1.2660 - val_accuracy: 0.5676
# Epoch 5/15
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.2193 - accuracy: 0.5679 - val_loss: 1.1949 - val_accuracy: 0.5741
# Epoch 6/15
# 1563/1563 [==============================] - 29s 19ms/step - loss: 1.1831 - accuracy: 0.5844 - val_loss: 1.1174 - val_accuracy: 0.6081
# Epoch 7/15
# ...

# %%
import datetime
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# %%
now = datetime.datetime.now

# %%
batch_size = 128
num_classes=5
epochs=5

# %%
img_rows, img_cols=28,28
filters = 32
pool_size = 2
kernel_size = 3

# %%
if K.image_data_format() == "channels_first":
    input_shape = (1, img_rows, img_cols)
else:
    input_shape = (img_rows, img_cols, 1)

# %%
def train_model(model, train, test, num_classes):
    x_train = train[0].reshape((train[0].shape[0],) + input_shape)
    x_test = test[0].reshape((test[0].shape[0],) + input_shape)
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
    x_train /= 255
    x_test /= 255
    print('x_train shape:', x_train.shape)
    print(x_train.shape[0], 'train samples')
    print(x_test.shape[0], 'test samples')
    
    y_train = keras.utils.to_categorical(train[1], num_classes)
    y_test = keras.utils.to_categorical(test[1], num_classes)
    
    model.compile(loss='categorical_crossentropy',
                  optimizer='adadelta',
                  metrics=['accuracy'])
    t = now()
    model.fit(x_train, y_train,
              batch_size=batch_size,
             epochs = epochs,
             verbose=1,
             validation_data=(x_test, y_test),
             shuffle=True)
    print('Training time: %s' % (now() - t))
    
    score = model.evaluate(x_test, y_test, verbose=0)
    print('Test score:', score[0])
    print('Test accuracy:', score[1])

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train_l5 = x_train[y_train < 5]
y_train_l5 = y_train[y_train < 5]
x_test_l5 = x_test[y_test < 5]
y_test_l5 = y_test[y_test < 5]

x_train_g5 = x_train[y_train >= 5]
y_train_g5 = y_train[y_train >= 5] - 5
x_test_g5 = x_test[y_test >= 5]
y_test_g5 = y_test[y_test >= 5] - 5
# Out:
# ...
# 11493376/11490434 [==============================] - 2s 0us/step

# %%
feature_layers = [
    Conv2D(filters, kernel_size,
          padding='valid',
          input_shape = input_shape),
    Activation('relu'),
    Conv2D(filters, kernel_size),
    Activation('relu'),
    MaxPooling2D(pool_size = pool_size),
    Dropout(0.25),
    Flatten()
]

# %%
classification_layers = [
    Dense(128),
    Activation('relu'),
    Dropout(0.5),
    Dense(num_classes),
    Activation('softmax')
]

# %%
model = Sequential(feature_layers + classification_layers)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_2 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# activation_4 (Activation)    (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# activation_5 (Activation)    (None, 24, 24, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# ...

# %%
train_model(model, 
           (x_train_g5, y_train_g5),
           (x_test_g5, y_test_g5),
           num_classes)
# Out:
# x_train shape: (29404, 28, 28, 1)
# 29404 train samples
# 4861 test samples
# Epoch 1/5
# 230/230 [==============================] - 27s 118ms/step - loss: 1.6064 - accuracy: 0.1962 - val_loss: 1.5868 - val_accuracy: 0.1792
# Epoch 2/5
# 230/230 [==============================] - 27s 116ms/step - loss: 1.5794 - accuracy: 0.2589 - val_loss: 1.5584 - val_accuracy: 0.3598
# Epoch 3/5
# 230/230 [==============================] - 30s 130ms/step - loss: 1.5524 - accuracy: 0.3267 - val_loss: 1.5283 - val_accuracy: 0.4836
# Epoch 4/5
# 230/230 [==============================] - 33s 143ms/step - loss: 1.5240 - accuracy: 0.3943 - val_loss: 1.4948 - val_accuracy: 0.5760
# Epoch 5/5
# 230/230 [==============================] - 33s 143ms/step - loss: 1.4917 - accuracy: 0.4543 - val_loss: 1.4571 - val_accuracy: 0.6404
# Training time: 0:02:30.798509
# Test score: 1.457055687904358
# Test accuracy: 0.6404032111167908

# %%
for l in feature_layers:
    l.trainable = False

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_2 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# activation_4 (Activation)    (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# activation_5 (Activation)    (None, 24, 24, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# ...

# %%
train_model(model, 
            (x_train_l5, y_train_l5),
            (x_test_l5, y_test_l5), num_classes)
# Out:
# x_train shape: (30596, 28, 28, 1)
# 30596 train samples
# 5139 test samples
# Epoch 1/5
# 240/240 [==============================] - 8s 32ms/step - loss: 1.5781 - accuracy: 0.2761 - val_loss: 1.5378 - val_accuracy: 0.4279
# Epoch 2/5
# 240/240 [==============================] - 8s 32ms/step - loss: 1.5295 - accuracy: 0.3778 - val_loss: 1.4859 - val_accuracy: 0.5871
# Epoch 3/5
# 240/240 [==============================] - 8s 34ms/step - loss: 1.4836 - accuracy: 0.4762 - val_loss: 1.4367 - val_accuracy: 0.6976
# Epoch 4/5
# 240/240 [==============================] - 8s 35ms/step - loss: 1.4361 - accuracy: 0.5642 - val_loss: 1.3883 - val_accuracy: 0.7836
# Epoch 5/5
# 240/240 [==============================] - 9s 37ms/step - loss: 1.3935 - accuracy: 0.6253 - val_loss: 1.3413 - val_accuracy: 0.8381
# Training time: 0:00:41.379610
# Test score: 1.3415062427520752
# Test accuracy: 0.838100790977478

# %%
# Create layers and define the model as above
feature_layers2 = [
    Conv2D(filters, kernel_size,
           padding='valid',
           input_shape=input_shape),
    Activation('relu'),
    Conv2D(filters, kernel_size),
    Activation('relu'),
    MaxPooling2D(pool_size=pool_size),
    Dropout(0.25),
    Flatten(),
]

classification_layers2 = [
    Dense(128),
    Activation('relu'),
    Dropout(0.5),
    Dense(num_classes),
    Activation('softmax')
]
model2 = Sequential(feature_layers2 + classification_layers2)
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# activation_8 (Activation)    (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# activation_9 (Activation)    (None, 24, 24, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 12, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4608)              0
# ...

# %%
train_model(model2,
           (x_train_g5, y_train_g5),
           (x_test_g5, y_test_g5), num_classes)
# Out:
# x_train shape: (29404, 28, 28, 1)
# 29404 train samples
# 4861 test samples
# Epoch 1/5
# 230/230 [==============================] - 30s 132ms/step - loss: 1.6134 - accuracy: 0.2165 - val_loss: 1.5829 - val_accuracy: 0.2220
# Epoch 2/5
# 230/230 [==============================] - 31s 133ms/step - loss: 1.5802 - accuracy: 0.2611 - val_loss: 1.5465 - val_accuracy: 0.3366
# Epoch 3/5
# 230/230 [==============================] - 32s 139ms/step - loss: 1.5463 - accuracy: 0.3202 - val_loss: 1.5091 - val_accuracy: 0.4534
# Epoch 4/5
# 230/230 [==============================] - 33s 142ms/step - loss: 1.5113 - accuracy: 0.3821 - val_loss: 1.4689 - val_accuracy: 0.5408
# Epoch 5/5
# 230/230 [==============================] - 33s 144ms/step - loss: 1.4721 - accuracy: 0.4426 - val_loss: 1.4243 - val_accuracy: 0.6190
# Training time: 0:02:39.898031
# Test score: 1.4242781400680542
# Test accuracy: 0.6190084218978882

# %%
for l in feature_layers2:
    l.trainable = False

# %%
train_model(model2,
           (x_train_g5, y_train_g5),
           (x_test_g5, y_test_g5),num_classes)
# Out:
# x_train shape: (29404, 28, 28, 1)
# 29404 train samples
# 4861 test samples
# Epoch 1/5
# 230/230 [==============================] - 9s 40ms/step - loss: 1.4343 - accuracy: 0.4981 - val_loss: 1.3889 - val_accuracy: 0.6589
# Epoch 2/5
# 230/230 [==============================] - 9s 40ms/step - loss: 1.4034 - accuracy: 0.5375 - val_loss: 1.3530 - val_accuracy: 0.6920
# Epoch 3/5
# 230/230 [==============================] - 9s 40ms/step - loss: 1.3720 - accuracy: 0.5735 - val_loss: 1.3174 - val_accuracy: 0.7155
# Epoch 4/5
# 230/230 [==============================] - 9s 40ms/step - loss: 1.3371 - accuracy: 0.6038 - val_loss: 1.2824 - val_accuracy: 0.7412
# Epoch 5/5
# 230/230 [==============================] - 9s 40ms/step - loss: 1.3044 - accuracy: 0.6332 - val_loss: 1.2482 - val_accuracy: 0.7573
# Training time: 0:00:46.537342
# Test score: 1.2481050491333008
# Test accuracy: 0.7572516202926636
